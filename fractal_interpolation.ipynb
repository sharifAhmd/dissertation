# %%
import csv
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# You can find all the required data [here](https://drive.google.com/drive/folders/1lzP-lq_JaVupDBBOqxL-6WYd2LkHZZ2t?usp=sharing)

# %%
## create this two folders
IN_DIR = "data_from_sol_22_updated"
OUT_DIR = "frctal_applied_from_sol_22"

# %%
## this contains the data for all the years and month to form a continous flow of data combining multiple dtaa sources like from different satelites
## the data is chosen based on number_of_missing values in a given data source.
df_data = pd.read_csv("continuous_data.csv")
df_data
# Out:
#                                 file_names satellite  year  month  total_rows
# 0    1986/g05_xrs_1m_19860101_19860131.csv    goes05  1986      1       44640  \
# 1    1986/g05_xrs_1m_19860201_19860228.csv    goes05  1986      2       40320
# 2    1986/g05_xrs_1m_19860301_19860331.csv    goes05  1986      3       44640
# 3    1986/g05_xrs_1m_19860401_19860430.csv    goes05  1986      4       43200
# 4    1986/g05_xrs_1m_19860501_19860531.csv    goes05  1986      5       44640
# ..                                     ...       ...   ...    ...         ...
# 403  2019/g14_xrs_1m_20191001_20191031.csv    goes14  2019     10       44640
# 404  2019/g14_xrs_1m_20191101_20191130.csv    goes14  2019     11       43200
# 405  2019/g15_xrs_1m_20191201_20191231.csv    goes15  2019     12       44640
# 406  2020/g15_xrs_1m_20200101_20200131.csv    goes15  2020      1       44640
# 407  2020/g14_xrs_1m_20200201_20200229.csv    goes14  2020      2       41760
#
#      missing_values
# 0               617
# 1               203
# 2              2686
# 3              3646
# 4               517
# ..              ...
# 403             986
# 404             161
# 405              36
# 406             584
# 407             278
#
# [408 rows x 6 columns]

# %%
def create_folder(year: int):
    #create folder to hold the data
    os.makedirs(f"{OUT_DIR}/{year}", exist_ok = True)

# %%
## the logic here is to fill the data using ffill method if total missing in a file is less than or equal 50 
for index, row in df_data.iterrows():
    if row.missing_values <= 50:
        df = pd.read_csv(os.path.join(IN_DIR, row.file_names))
        create_folder(row.year)
        before_filling = (df['xl'] == -99999).sum()
        
        #ffill data where missing_value count <=50
        df.replace(-99999, pd.NA, inplace=True)
        df.fillna(method='ffill', inplace=True)
        
        after_filling = (df['xl'] == -99999).sum()
        # save updated data
        df.to_csv(os.path.join(OUT_DIR, row.file_names), index = False)

# %%
df_data[df_data['missing_values'] <= 50]
# Out:
#                                 file_names satellite  year  month  total_rows
# 28   1988/g07_xrs_1m_19880501_19880531.csv    goes07  1988      5       44640  \
# 34   1988/g07_xrs_1m_19881101_19881130.csv    goes07  1988     11       43200
# 40   1989/g07_xrs_1m_19890501_19890531.csv    goes07  1989      5       44640
# 41   1989/g07_xrs_1m_19890601_19890630.csv    goes07  1989      6       43200
# 58   1990/g07_xrs_1m_19901101_19901130.csv    goes07  1990     11       43200
# ..                                     ...       ...   ...    ...         ...
# 381  2017/g15_xrs_1m_20171201_20171231.csv    goes15  2017     12       44640
# 386  2018/g14_xrs_1m_20180501_20180531.csv    goes14  2018      5       44640
# 393  2018/g14_xrs_1m_20181201_20181231.csv    goes14  2018     12       44640
# 400  2019/g14_xrs_1m_20190701_20190731.csv    goes14  2019      7       44640
# 405  2019/g15_xrs_1m_20191201_20191231.csv    goes15  2019     12       44640
#
#      missing_values
# 28               50
# 34               32
# 40               49
# 41               34
# 58               28
# ..              ...
# 381              44
# 386              46
# 393              32
# 400              40
# 405              36
#
# [68 rows x 6 columns]

# %%
# it holds the data which files  missing values exceeds more than 50 rows
df_missing_info = df_data[df_data['missing_values'] > 50].reset_index(drop = True)
df_missing_info
# Out:
#                                 file_names satellite  year  month  total_rows
# 0    1986/g05_xrs_1m_19860101_19860131.csv    goes05  1986      1       44640  \
# 1    1986/g05_xrs_1m_19860201_19860228.csv    goes05  1986      2       40320
# 2    1986/g05_xrs_1m_19860301_19860331.csv    goes05  1986      3       44640
# 3    1986/g05_xrs_1m_19860401_19860430.csv    goes05  1986      4       43200
# 4    1986/g05_xrs_1m_19860501_19860531.csv    goes05  1986      5       44640
# ..                                     ...       ...   ...    ...         ...
# 335  2019/g15_xrs_1m_20190901_20190930.csv    goes15  2019      9       43200
# 336  2019/g14_xrs_1m_20191001_20191031.csv    goes14  2019     10       44640
# 337  2019/g14_xrs_1m_20191101_20191130.csv    goes14  2019     11       43200
# 338  2020/g15_xrs_1m_20200101_20200131.csv    goes15  2020      1       44640
# 339  2020/g14_xrs_1m_20200201_20200229.csv    goes14  2020      2       41760
#
#      missing_values
# 0               617
# 1               203
# 2              2686
# 3              3646
# 4               517
# ..              ...
# 335            1962
# 336             986
# 337             161
# 338             584
# 339             278
#
# [340 rows x 6 columns]

# %%
import numpy as np
import scipy, random 
import matplotlib.pyplot as plt
def d( x ):
    # expects an enumerable, subtracts the right endpoint from the left
    return float(x[-1]-x[0])


def an( x, i ):
    # the (0,0) element in the rotation matrix of the iterated function system (IFS)
    return ( x[i] - x[i-1] )/d(x)


def dn( x, i ):
    # the (0) element in the translation vector of the IFS
    return ( x[-1]*x[i-1] - x[0]*x[i] )/d(x)


def cn( x, y, i, sn ):
    # the (1,0) element in the rotation matrix of the IFS
    return ( y[i] - y[i-1] )/d(x) - sn*( y[-1] - y[0] )/d(x)


def en( x, y, i, sn ):
    # the (1) element in the translation vector of the IFS
    return ( x[-1]*y[i-1] - x[0]*y[i])/d(x) - sn*( x[-1]*y[0] - x[0]*y[-1] )/d(x)

def Wn( X, U, i, sn ):
    '''
    the iterated function sytem
      R is the rotation matrix
      T is the translation vector
    computes
      R*X + T
    '''
    # rotation matrix
    R = np.matrix([[ an(U[:,0],i), 0 ],\
                   [ cn(U[:,0],U[:,1],i,sn), sn ]])
    # transalation vector
    T = np.matrix([[ dn(U[:,0],i) ],\
                   [ en(U[:,0],U[:,1],i,sn) ]])
    # calculate R*X + T
    tmp = R * np.matrix(X).T + T
    # return the new points
    xp, yp = np.array( tmp.T )[0]
    return xp, yp
    
def FIF( U, nth, sn, balance=False ):
    # the fractal interpolating function
    X = U.copy()
    x, y = list( X[:,0] ), list( X[:,1] )
    M = U.shape[0]

    for i in range(nth):
        # call an IFS for each segment
        for j in range( 1,M ):
            xp, yp = Wn( X[i], U, j, sn )
            x.append( xp )
            y.append( yp )
            if balance:
                xp, yp = Wn( X[i], U, j, -sn )
                x.append( xp )
                y.append( yp )
    x = np.array(x)
    y = np.array(y)
    # this puts the interpolated
    # data points at the bottom of X
    X = np.vstack((x,y)).T
    X = X[ X[:,0].argsort() ]
    # these two lines rearrage X so that the interpolated
    # data points are between the original data points
    null, indices = np.unique( X[:,0], return_index=True )
    X = X[ indices ]
    return X

# %%
def select_nth_values_and_build_df(df_with_missing, nth = 10):
    df_with_missing["xs_copy"] = df_with_missing["xs"]
    df_with_missing["xl_copy"] = df_with_missing["xl"]

    # Get the last row of the DataFrame
    last_row = df_with_missing.iloc[-1]

    # Create a new index for the new row
    new_index = len(df_with_missing)

    # Add the new row to the DataFrame with a different index
    # this extra row helps to keep the same length after the interpolation
    df_with_missing.loc[new_index] = last_row

    # bfill and ffill all the missing rows.
    # the idea here is to interpolate data on all the filled values and 
    # then take only the missing values in the final df
    df_with_missing['xs_copy'] = df_with_missing['xs_copy'].replace(-99999, method='bfill')
    df_with_missing['xl_copy'] = df_with_missing['xl_copy'].replace(-99999, method='bfill')
    df_with_missing['xs_copy'] = df_with_missing['xs_copy'].replace(-99999, method='ffill')
    df_with_missing['xl_copy'] = df_with_missing['xl_copy'].replace(-99999, method='ffill')

    ## there is also some data that are corrupted and contains values 32700
    df_with_missing['xs_copy'] = df_with_missing['xs_copy'].replace(32700, method='bfill')
    df_with_missing['xl_copy'] = df_with_missing['xl_copy'].replace(32700, method='bfill')
    df_with_missing['xs_copy'] = df_with_missing['xs_copy'].replace(32700, method='ffill')
    df_with_missing['xl_copy'] = df_with_missing['xl_copy'].replace(32700, method='ffill')

    df_nth_taken = df_with_missing[::nth].reset_index(drop = True)
    return df_nth_taken

# %%
def apply_interpolation_and_get_data(df_nth_taken, df_with_missing, nth):
    xs = df_nth_taken["xs_copy"].tolist()
    xl = df_nth_taken["xl_copy"].tolist()
    indexs = df_nth_taken.index.tolist()

    np_xs = np.array(xs)
    np_xl = np.array(xl)
    np_indexs = np.array(indexs)

    stacked_xs = np.vstack((np_indexs, np_xs)).T
    stacked_xl = np.vstack((np_indexs, np_xl)).T

    ## 0.01 is our vertical scaling factor. You can control it to get new interpolated data
    interpolated_xs = FIF(stacked_xs, nth, 0.01)
    interpolated_xl = FIF(stacked_xl, nth, 0.01)

    df_with_missing["xs_interpolated"] = interpolated_xs[:, 1]
    df_with_missing["xl_interpolated"] = interpolated_xl[:, 1]

    ## filtering out the rows based on the logic like:
    ## if the original value is presented them we are taking them
    ## if it is not presented them we will take newly interpolated values.
    df_with_missing['xs'] = df_with_missing.apply(lambda row: row['xs_interpolated'] if row['xs'] == -99999 else row['xs'], axis=1)
    df_with_missing['xl'] = df_with_missing.apply(lambda row: row['xl_interpolated'] if row['xl'] == -99999 else row['xs'], axis=1)

    df_interpolated = df_with_missing[["time_tag", "xs", "xl"]]
    
    return df_interpolated

# %%
file_names = df_missing_info["file_names"].tolist()
for i, file_name in enumerate(file_names):
    year = file_name.split("/")[0]
    create_folder(year)
    print("path:", os.path.join(IN_DIR, file_name))
    df_with_missing = pd.read_csv(os.path.join(IN_DIR, file_name))

    ## Here the idea is to take each tenth values of the given file
    ## and then interpolate the in between data and after that filted them
    df_nth_taken = select_nth_values_and_build_df(df_with_missing, nth = 10)
    
    df_interpolated = apply_interpolation_and_get_data(df_nth_taken, df_with_missing, nth = 10)
    
    ## dropping it as we have added it extra in our process
    df_interpolated = df_interpolated.drop(df_interpolated.index[-1])
    
    df_interpolated.to_csv(os.path.join(OUT_DIR, file_name), index = False)
# Out:
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860101_19860131.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860201_19860228.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860301_19860331.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860401_19860430.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860501_19860531.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860601_19860630.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860701_19860731.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860801_19860831.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19860901_19860930.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19861001_19861031.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19861101_19861130.csv
# path: data_from_sol_22_updated/1986/g05_xrs_1m_19861201_19861231.csv
# path: data_from_sol_22_updated/1987/g06_xrs_1m_19870101_19870131.csv
# path: data_from_sol_22_updated/1987/g06_xrs_1m_19870201_19870228.csv
# path: data_from_sol_22_updated/1987/g06_xrs_1m_19870301_19870331.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19870401_19870430.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19870501_19870531.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19870601_19870630.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19870701_19870731.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19870801_19870831.csv
# path: data_from_sol_22_updated/1987/g06_xrs_1m_19870901_19870930.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19871001_19871031.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19871101_19871130.csv
# path: data_from_sol_22_updated/1987/g07_xrs_1m_19871201_19871231.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880101_19880131.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880201_19880229.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880301_19880331.csv
# path: data_from_sol_22_updated/1988/g06_xrs_1m_19880401_19880430.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880601_19880630.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880701_19880731.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880801_19880831.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19880901_19880930.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19881001_19881031.csv
# path: data_from_sol_22_updated/1988/g07_xrs_1m_19881201_19881231.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890101_19890131.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890201_19890228.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890301_19890331.csv
# path: data_from_sol_22_updated/1989/g06_xrs_1m_19890401_19890430.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890701_19890731.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890801_19890831.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19890901_19890930.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19891001_19891031.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19891101_19891130.csv
# path: data_from_sol_22_updated/1989/g07_xrs_1m_19891201_19891231.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900101_19900131.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900201_19900228.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900301_19900331.csv
# path: data_from_sol_22_updated/1990/g06_xrs_1m_19900401_19900430.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900501_19900531.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900601_19900630.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900701_19900731.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900801_19900831.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19900901_19900930.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19901001_19901031.csv
# path: data_from_sol_22_updated/1990/g07_xrs_1m_19901201_19901231.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910101_19910131.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910201_19910228.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910301_19910331.csv
# path: data_from_sol_22_updated/1991/g06_xrs_1m_19910401_19910430.csv
# path: data_from_sol_22_updated/1991/g06_xrs_1m_19910501_19910531.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910701_19910731.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910801_19910831.csv
# path: data_from_sol_22_updated/1991/g07_xrs_1m_19910901_19910930.csv
# path: data_from_sol_22_updated/1991/g06_xrs_1m_19911001_19911031.csv
# path: data_from_sol_22_updated/1992/g06_xrs_1m_19920101_19920131.csv
# path: data_from_sol_22_updated/1992/g07_xrs_1m_19920201_19920229.csv
# path: data_from_sol_22_updated/1992/g07_xrs_1m_19920301_19920331.csv
# path: data_from_sol_22_updated/1992/g06_xrs_1m_19920401_19920430.csv
# path: data_from_sol_22_updated/1992/g07_xrs_1m_19920501_19920531.csv
# path: data_from_sol_22_updated/1992/g07_xrs_1m_19920601_19920630.csv
# path: data_from_sol_22_updated/1992/g06_xrs_1m_19921001_19921031.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930101_19930131.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930201_19930228.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930301_19930331.csv
# path: data_from_sol_22_updated/1993/g06_xrs_1m_19930501_19930531.csv
# path: data_from_sol_22_updated/1993/g06_xrs_1m_19930601_19930630.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930701_19930731.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930801_19930831.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19930901_19930930.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19931001_19931031.csv
# path: data_from_sol_22_updated/1993/g06_xrs_1m_19931101_19931130.csv
# path: data_from_sol_22_updated/1993/g07_xrs_1m_19931201_19931231.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940201_19940228.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940301_19940331.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940401_19940430.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940501_19940531.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940601_19940630.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940701_19940731.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940801_19940831.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19940901_19940930.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19941001_19941031.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19941101_19941130.csv
# path: data_from_sol_22_updated/1994/g07_xrs_1m_19941201_19941231.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950201_19950228.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950301_19950331.csv
# path: data_from_sol_22_updated/1995/g07_xrs_1m_19950401_19950430.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950501_19950531.csv
# path: data_from_sol_22_updated/1995/g07_xrs_1m_19950601_19950630.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950701_19950731.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950801_19950831.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19950901_19950930.csv
# path: data_from_sol_22_updated/1995/g08_xrs_1m_19951001_19951031.csv
# path: data_from_sol_22_updated/1995/g07_xrs_1m_19951101_19951130.csv
# path: data_from_sol_22_updated/1995/g07_xrs_1m_19951201_19951231.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19960101_19960131.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19960201_19960229.csv
# path: data_from_sol_22_updated/1996/g07_xrs_1m_19960301_19960331.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19960401_19960430.csv
# path: data_from_sol_22_updated/1996/g09_xrs_1m_19960501_19960531.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19960601_19960630.csv
# path: data_from_sol_22_updated/1996/g09_xrs_1m_19960701_19960731.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19960801_19960831.csv
# path: data_from_sol_22_updated/1996/g09_xrs_1m_19960901_19960930.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19961001_19961031.csv
# path: data_from_sol_22_updated/1996/g08_xrs_1m_19961101_19961130.csv
# path: data_from_sol_22_updated/1996/g09_xrs_1m_19961201_19961231.csv
# path: data_from_sol_22_updated/1997/g09_xrs_1m_19970101_19970131.csv
# path: data_from_sol_22_updated/1997/g09_xrs_1m_19970201_19970228.csv
# path: data_from_sol_22_updated/1997/g09_xrs_1m_19970301_19970331.csv
# path: data_from_sol_22_updated/1997/g08_xrs_1m_19970401_19970430.csv
# path: data_from_sol_22_updated/1997/g09_xrs_1m_19970501_19970531.csv
# path: data_from_sol_22_updated/1997/g08_xrs_1m_19970601_19970630.csv
# path: data_from_sol_22_updated/1997/g08_xrs_1m_19970801_19970831.csv
# path: data_from_sol_22_updated/1997/g08_xrs_1m_19970901_19970930.csv
# path: data_from_sol_22_updated/1997/g09_xrs_1m_19971001_19971031.csv
# path: data_from_sol_22_updated/1998/g08_xrs_1m_19980101_19980131.csv
# path: data_from_sol_22_updated/1998/g08_xrs_1m_19980201_19980228.csv
# path: data_from_sol_22_updated/1998/g09_xrs_1m_19980301_19980331.csv
# path: data_from_sol_22_updated/1998/g08_xrs_1m_19980401_19980430.csv
# path: data_from_sol_22_updated/1998/g09_xrs_1m_19980501_19980531.csv
# path: data_from_sol_22_updated/1998/g10_xrs_1m_19980801_19980831.csv
# path: data_from_sol_22_updated/1998/g08_xrs_1m_19980901_19980930.csv
# path: data_from_sol_22_updated/1998/g08_xrs_1m_19981001_19981031.csv
# path: data_from_sol_22_updated/1999/g10_xrs_1m_19990101_19990131.csv
# path: data_from_sol_22_updated/1999/g10_xrs_1m_19990201_19990228.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990301_19990331.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990401_19990430.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990501_19990531.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990601_19990630.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990701_19990731.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990801_19990831.csv
# path: data_from_sol_22_updated/1999/g08_xrs_1m_19990901_19990930.csv
# path: data_from_sol_22_updated/1999/g10_xrs_1m_19991001_19991031.csv
# path: data_from_sol_22_updated/2000/g10_xrs_1m_20000101_20000131.csv
# path: data_from_sol_22_updated/2000/g10_xrs_1m_20000201_20000229.csv
# path: data_from_sol_22_updated/2000/g08_xrs_1m_20000301_20000331.csv
# path: data_from_sol_22_updated/2000/g08_xrs_1m_20000401_20000430.csv
# path: data_from_sol_22_updated/2000/g08_xrs_1m_20000701_20000731.csv
# path: data_from_sol_22_updated/2000/g10_xrs_1m_20000801_20000831.csv
# path: data_from_sol_22_updated/2000/g10_xrs_1m_20000901_20000930.csv
# path: data_from_sol_22_updated/2000/g08_xrs_1m_20001001_20001031.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20010101_20010131.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20010201_20010228.csv
# path: data_from_sol_22_updated/2001/g08_xrs_1m_20010301_20010331.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20010401_20010430.csv
# path: data_from_sol_22_updated/2001/g08_xrs_1m_20010501_20010531.csv
# path: data_from_sol_22_updated/2001/g08_xrs_1m_20010601_20010630.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20010701_20010731.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20010801_20010831.csv
# path: data_from_sol_22_updated/2001/g08_xrs_1m_20010901_20010930.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20011001_20011031.csv
# path: data_from_sol_22_updated/2001/g10_xrs_1m_20011201_20011231.csv
# path: data_from_sol_22_updated/2002/g10_xrs_1m_20020101_20020131.csv
# path: data_from_sol_22_updated/2002/g10_xrs_1m_20020201_20020228.csv
# path: data_from_sol_22_updated/2002/g08_xrs_1m_20020301_20020331.csv
# path: data_from_sol_22_updated/2002/g10_xrs_1m_20020401_20020430.csv
# path: data_from_sol_22_updated/2002/g08_xrs_1m_20020601_20020630.csv
# path: data_from_sol_22_updated/2002/g10_xrs_1m_20020701_20020731.csv
# path: data_from_sol_22_updated/2002/g08_xrs_1m_20020801_20020831.csv
# path: data_from_sol_22_updated/2002/g08_xrs_1m_20020901_20020930.csv
# path: data_from_sol_22_updated/2002/g10_xrs_1m_20021001_20021031.csv
# path: data_from_sol_22_updated/2003/g10_xrs_1m_20030101_20030131.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20030201_20030228.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20030301_20030331.csv
# path: data_from_sol_22_updated/2003/g10_xrs_1m_20030401_20030430.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20030501_20030531.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20030601_20030630.csv
# path: data_from_sol_22_updated/2003/g10_xrs_1m_20030801_20030831.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20030901_20030930.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20031001_20031031.csv
# path: data_from_sol_22_updated/2003/g12_xrs_1m_20031201_20031231.csv
# path: data_from_sol_22_updated/2004/g12_xrs_1m_20040201_20040229.csv
# path: data_from_sol_22_updated/2004/g12_xrs_1m_20040301_20040331.csv
# path: data_from_sol_22_updated/2004/g10_xrs_1m_20040401_20040430.csv
# path: data_from_sol_22_updated/2004/g10_xrs_1m_20040801_20040831.csv
# path: data_from_sol_22_updated/2004/g12_xrs_1m_20040901_20040930.csv
# path: data_from_sol_22_updated/2004/g12_xrs_1m_20041001_20041031.csv
# path: data_from_sol_22_updated/2004/g12_xrs_1m_20041101_20041130.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20050201_20050228.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20050301_20050331.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20050401_20050430.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20050501_20050531.csv
# path: data_from_sol_22_updated/2005/g10_xrs_1m_20050601_20050630.csv
# path: data_from_sol_22_updated/2005/g10_xrs_1m_20050701_20050731.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20050801_20050831.csv
# path: data_from_sol_22_updated/2005/g10_xrs_1m_20050901_20050930.csv
# path: data_from_sol_22_updated/2005/g10_xrs_1m_20051001_20051031.csv
# path: data_from_sol_22_updated/2005/g12_xrs_1m_20051201_20051231.csv
# path: data_from_sol_22_updated/2006/g10_xrs_1m_20060201_20060228.csv
# path: data_from_sol_22_updated/2006/g12_xrs_1m_20060301_20060331.csv
# path: data_from_sol_22_updated/2006/g10_xrs_1m_20060401_20060430.csv
# path: data_from_sol_22_updated/2006/g12_xrs_1m_20060601_20060630.csv
# path: data_from_sol_22_updated/2006/g11_xrs_1m_20060801_20060831.csv
# path: data_from_sol_22_updated/2006/g12_xrs_1m_20060901_20060930.csv
# path: data_from_sol_22_updated/2006/g11_xrs_1m_20061001_20061031.csv
# path: data_from_sol_22_updated/2006/g11_xrs_1m_20061101_20061130.csv
# path: data_from_sol_22_updated/2006/g11_xrs_1m_20061201_20061231.csv
# path: data_from_sol_22_updated/2007/g12_xrs_1m_20070101_20070131.csv
# path: data_from_sol_22_updated/2007/g12_xrs_1m_20070201_20070228.csv
# path: data_from_sol_22_updated/2007/g12_xrs_1m_20070301_20070331.csv
# path: data_from_sol_22_updated/2007/g10_xrs_1m_20070401_20070430.csv
# path: data_from_sol_22_updated/2007/g11_xrs_1m_20070501_20070531.csv
# path: data_from_sol_22_updated/2007/g10_xrs_1m_20070601_20070630.csv
# path: data_from_sol_22_updated/2007/g11_xrs_1m_20070801_20070831.csv
# path: data_from_sol_22_updated/2007/g11_xrs_1m_20070901_20070930.csv
# path: data_from_sol_22_updated/2007/g10_xrs_1m_20071001_20071031.csv
# path: data_from_sol_22_updated/2007/g11_xrs_1m_20071101_20071130.csv
# path: data_from_sol_22_updated/2007/g11_xrs_1m_20071201_20071231.csv
# path: data_from_sol_22_updated/2008/g11_xrs_1m_20080101_20080131.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080201_20080229.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080301_20080331.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080401_20080430.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080501_20080531.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080601_20080630.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080801_20080831.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20080901_20080930.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20081001_20081031.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20081101_20081130.csv
# path: data_from_sol_22_updated/2008/g10_xrs_1m_20081201_20081231.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090101_20090131.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090201_20090228.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090301_20090331.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090401_20090430.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090601_20090630.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20090801_20090831.csv
# path: data_from_sol_22_updated/2009/g14_xrs_1m_20090901_20090930.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20091001_20091031.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20091101_20091130.csv
# path: data_from_sol_22_updated/2009/g10_xrs_1m_20091201_20091231.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100101_20100131.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100201_20100228.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100301_20100331.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100401_20100430.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100501_20100531.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100701_20100731.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100801_20100831.csv
# path: data_from_sol_22_updated/2010/g14_xrs_1m_20100901_20100930.csv
# path: data_from_sol_22_updated/2010/g15_xrs_1m_20101001_20101031.csv
# path: data_from_sol_22_updated/2010/g15_xrs_1m_20101101_20101130.csv
# path: data_from_sol_22_updated/2010/g15_xrs_1m_20101201_20101231.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110201_20110228.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110301_20110331.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110401_20110430.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110501_20110531.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110601_20110630.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110701_20110731.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110801_20110831.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20110901_20110930.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20111001_20111031.csv
# path: data_from_sol_22_updated/2011/g15_xrs_1m_20111201_20111231.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120101_20120131.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120201_20120229.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120401_20120430.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120501_20120531.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120801_20120831.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20120901_20120930.csv
# path: data_from_sol_22_updated/2012/g14_xrs_1m_20121001_20121031.csv
# path: data_from_sol_22_updated/2012/g15_xrs_1m_20121101_20121130.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130101_20130131.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130201_20130228.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130301_20130331.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130401_20130430.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130501_20130531.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130801_20130831.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20130901_20130930.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20131001_20131031.csv
# path: data_from_sol_22_updated/2013/g15_xrs_1m_20131101_20131130.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140101_20140131.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140201_20140228.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140301_20140331.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140401_20140430.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140501_20140531.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140701_20140731.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140801_20140831.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20140901_20140930.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20141001_20141031.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20141101_20141130.csv
# path: data_from_sol_22_updated/2014/g15_xrs_1m_20141201_20141231.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150101_20150131.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150201_20150228.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150301_20150331.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150401_20150430.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150501_20150531.csv
# path: data_from_sol_22_updated/2015/g13_xrs_1m_20150601_20150630.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150701_20150731.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20150901_20150930.csv
# path: data_from_sol_22_updated/2015/g13_xrs_1m_20151001_20151031.csv
# path: data_from_sol_22_updated/2015/g15_xrs_1m_20151101_20151130.csv
# path: data_from_sol_22_updated/2015/g13_xrs_1m_20151201_20151231.csv
# path: data_from_sol_22_updated/2016/g15_xrs_1m_20160101_20160131.csv
# path: data_from_sol_22_updated/2016/g15_xrs_1m_20160201_20160229.csv
# path: data_from_sol_22_updated/2016/g15_xrs_1m_20160401_20160430.csv
# path: data_from_sol_22_updated/2016/g14_xrs_1m_20160501_20160531.csv
# path: data_from_sol_22_updated/2016/g15_xrs_1m_20160601_20160630.csv
# path: data_from_sol_22_updated/2016/g13_xrs_1m_20160801_20160831.csv
# path: data_from_sol_22_updated/2016/g13_xrs_1m_20160901_20160930.csv
# path: data_from_sol_22_updated/2016/g13_xrs_1m_20161001_20161031.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20170101_20170131.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20170201_20170228.csv
# path: data_from_sol_22_updated/2017/g15_xrs_1m_20170301_20170331.csv
# path: data_from_sol_22_updated/2017/g15_xrs_1m_20170401_20170430.csv
# path: data_from_sol_22_updated/2017/g15_xrs_1m_20170501_20170531.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20170601_20170630.csv
# path: data_from_sol_22_updated/2017/g15_xrs_1m_20170701_20170731.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20170801_20170831.csv
# path: data_from_sol_22_updated/2017/g15_xrs_1m_20170901_20170930.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20171001_20171031.csv
# path: data_from_sol_22_updated/2017/g13_xrs_1m_20171101_20171130.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180101_20180131.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180201_20180228.csv
# path: data_from_sol_22_updated/2018/g15_xrs_1m_20180301_20180331.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180401_20180430.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180601_20180630.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180701_20180731.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20180801_20180831.csv
# path: data_from_sol_22_updated/2018/g15_xrs_1m_20180901_20180930.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20181001_20181031.csv
# path: data_from_sol_22_updated/2018/g14_xrs_1m_20181101_20181130.csv
# path: data_from_sol_22_updated/2019/g15_xrs_1m_20190101_20190131.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20190201_20190228.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20190301_20190331.csv
# path: data_from_sol_22_updated/2019/g15_xrs_1m_20190401_20190430.csv
# path: data_from_sol_22_updated/2019/g15_xrs_1m_20190501_20190531.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20190601_20190630.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20190801_20190831.csv
# path: data_from_sol_22_updated/2019/g15_xrs_1m_20190901_20190930.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20191001_20191031.csv
# path: data_from_sol_22_updated/2019/g14_xrs_1m_20191101_20191130.csv
# path: data_from_sol_22_updated/2020/g15_xrs_1m_20200101_20200131.csv
# path: data_from_sol_22_updated/2020/g14_xrs_1m_20200201_20200229.csv

# %% [markdown]
# ## Simple data quality checks

# %%
##  checking if there is any more missing values in our data
file_names = df_data["file_names"].tolist()
for i, file_name in enumerate(file_names):
    df = pd.read_csv(os.path.join(OUT_DIR, file_name))
    s = (df['xl'] == -99999).sum()
    print(file_name, s)
# Out:
# 1986/g05_xrs_1m_19860101_19860131.csv 0
# 1986/g05_xrs_1m_19860201_19860228.csv 0
# 1986/g05_xrs_1m_19860301_19860331.csv 0
# 1986/g05_xrs_1m_19860401_19860430.csv 0
# 1986/g05_xrs_1m_19860501_19860531.csv 0
# 1986/g05_xrs_1m_19860601_19860630.csv 0
# 1986/g05_xrs_1m_19860701_19860731.csv 0
# 1986/g05_xrs_1m_19860801_19860831.csv 0
# 1986/g05_xrs_1m_19860901_19860930.csv 0
# 1986/g05_xrs_1m_19861001_19861031.csv 0
# 1986/g05_xrs_1m_19861101_19861130.csv 0
# 1986/g05_xrs_1m_19861201_19861231.csv 0
# 1987/g06_xrs_1m_19870101_19870131.csv 0
# 1987/g06_xrs_1m_19870201_19870228.csv 0
# 1987/g06_xrs_1m_19870301_19870331.csv 0
# 1987/g07_xrs_1m_19870401_19870430.csv 0
# 1987/g07_xrs_1m_19870501_19870531.csv 0
# 1987/g07_xrs_1m_19870601_19870630.csv 0
# 1987/g07_xrs_1m_19870701_19870731.csv 0
# 1987/g07_xrs_1m_19870801_19870831.csv 0
# 1987/g06_xrs_1m_19870901_19870930.csv 0
# 1987/g07_xrs_1m_19871001_19871031.csv 0
# 1987/g07_xrs_1m_19871101_19871130.csv 0
# 1987/g07_xrs_1m_19871201_19871231.csv 0
# 1988/g07_xrs_1m_19880101_19880131.csv 0
# 1988/g07_xrs_1m_19880201_19880229.csv 0
# 1988/g07_xrs_1m_19880301_19880331.csv 0
# 1988/g06_xrs_1m_19880401_19880430.csv 0
# 1988/g07_xrs_1m_19880501_19880531.csv 0
# 1988/g07_xrs_1m_19880601_19880630.csv 0
# 1988/g07_xrs_1m_19880701_19880731.csv 0
# 1988/g07_xrs_1m_19880801_19880831.csv 0
# 1988/g07_xrs_1m_19880901_19880930.csv 0
# 1988/g07_xrs_1m_19881001_19881031.csv 0
# 1988/g07_xrs_1m_19881101_19881130.csv 0
# 1988/g07_xrs_1m_19881201_19881231.csv 0
# 1989/g07_xrs_1m_19890101_19890131.csv 0
# 1989/g07_xrs_1m_19890201_19890228.csv 0
# 1989/g07_xrs_1m_19890301_19890331.csv 0
# 1989/g06_xrs_1m_19890401_19890430.csv 0
# 1989/g07_xrs_1m_19890501_19890531.csv 0
# 1989/g07_xrs_1m_19890601_19890630.csv 0
# 1989/g07_xrs_1m_19890701_19890731.csv 0
# 1989/g07_xrs_1m_19890801_19890831.csv 0
# 1989/g07_xrs_1m_19890901_19890930.csv 0
# 1989/g07_xrs_1m_19891001_19891031.csv 0
# 1989/g07_xrs_1m_19891101_19891130.csv 0
# 1989/g07_xrs_1m_19891201_19891231.csv 0
# 1990/g07_xrs_1m_19900101_19900131.csv 0
# 1990/g07_xrs_1m_19900201_19900228.csv 0
# 1990/g07_xrs_1m_19900301_19900331.csv 0
# 1990/g06_xrs_1m_19900401_19900430.csv 0
# 1990/g07_xrs_1m_19900501_19900531.csv 0
# 1990/g07_xrs_1m_19900601_19900630.csv 0
# 1990/g07_xrs_1m_19900701_19900731.csv 0
# 1990/g07_xrs_1m_19900801_19900831.csv 0
# 1990/g07_xrs_1m_19900901_19900930.csv 0
# 1990/g07_xrs_1m_19901001_19901031.csv 0
# 1990/g07_xrs_1m_19901101_19901130.csv 0
# 1990/g07_xrs_1m_19901201_19901231.csv 0
# 1991/g07_xrs_1m_19910101_19910131.csv 0
# 1991/g07_xrs_1m_19910201_19910228.csv 0
# 1991/g07_xrs_1m_19910301_19910331.csv 0
# 1991/g06_xrs_1m_19910401_19910430.csv 0
# 1991/g06_xrs_1m_19910501_19910531.csv 0
# 1991/g07_xrs_1m_19910601_19910630.csv 0
# 1991/g07_xrs_1m_19910701_19910731.csv 0
# 1991/g07_xrs_1m_19910801_19910831.csv 0
# 1991/g07_xrs_1m_19910901_19910930.csv 0
# 1991/g06_xrs_1m_19911001_19911031.csv 0
# 1991/g07_xrs_1m_19911101_19911130.csv 0
# 1991/g07_xrs_1m_19911201_19911231.csv 0
# 1992/g06_xrs_1m_19920101_19920131.csv 0
# 1992/g07_xrs_1m_19920201_19920229.csv 0
# 1992/g07_xrs_1m_19920301_19920331.csv 0
# 1992/g06_xrs_1m_19920401_19920430.csv 0
# 1992/g07_xrs_1m_19920501_19920531.csv 0
# 1992/g07_xrs_1m_19920601_19920630.csv 0
# 1992/g07_xrs_1m_19920701_19920731.csv 0
# 1992/g06_xrs_1m_19920801_19920831.csv 0
# 1992/g06_xrs_1m_19920901_19920930.csv 0
# 1992/g06_xrs_1m_19921001_19921031.csv 0
# 1992/g07_xrs_1m_19921101_19921130.csv 0
# 1992/g07_xrs_1m_19921201_19921231.csv 0
# 1993/g07_xrs_1m_19930101_19930131.csv 0
# 1993/g07_xrs_1m_19930201_19930228.csv 0
# 1993/g07_xrs_1m_19930301_19930331.csv 0
# 1993/g07_xrs_1m_19930401_19930430.csv 0
# 1993/g06_xrs_1m_19930501_19930531.csv 0
# 1993/g06_xrs_1m_19930601_19930630.csv 0
# 1993/g07_xrs_1m_19930701_19930731.csv 0
# 1993/g07_xrs_1m_19930801_19930831.csv 0
# 1993/g07_xrs_1m_19930901_19930930.csv 0
# 1993/g07_xrs_1m_19931001_19931031.csv 0
# 1993/g06_xrs_1m_19931101_19931130.csv 0
# 1993/g07_xrs_1m_19931201_19931231.csv 0
# 1994/g07_xrs_1m_19940101_19940131.csv 0
# 1994/g07_xrs_1m_19940201_19940228.csv 0
# 1994/g07_xrs_1m_19940301_19940331.csv 0
# 1994/g07_xrs_1m_19940401_19940430.csv 0
# 1994/g07_xrs_1m_19940501_19940531.csv 0
# 1994/g07_xrs_1m_19940601_19940630.csv 0
# 1994/g07_xrs_1m_19940701_19940731.csv 0
# 1994/g07_xrs_1m_19940801_19940831.csv 0
# 1994/g07_xrs_1m_19940901_19940930.csv 0
# 1994/g07_xrs_1m_19941001_19941031.csv 0
# 1994/g07_xrs_1m_19941101_19941130.csv 0
# 1994/g07_xrs_1m_19941201_19941231.csv 0
# 1995/g07_xrs_1m_19950101_19950131.csv 0
# 1995/g08_xrs_1m_19950201_19950228.csv 0
# 1995/g08_xrs_1m_19950301_19950331.csv 0
# 1995/g07_xrs_1m_19950401_19950430.csv 0
# 1995/g08_xrs_1m_19950501_19950531.csv 0
# 1995/g07_xrs_1m_19950601_19950630.csv 0
# 1995/g08_xrs_1m_19950701_19950731.csv 0
# 1995/g08_xrs_1m_19950801_19950831.csv 0
# 1995/g08_xrs_1m_19950901_19950930.csv 0
# 1995/g08_xrs_1m_19951001_19951031.csv 0
# 1995/g07_xrs_1m_19951101_19951130.csv 0
# 1995/g07_xrs_1m_19951201_19951231.csv 0
# 1996/g08_xrs_1m_19960101_19960131.csv 0
# 1996/g08_xrs_1m_19960201_19960229.csv 0
# 1996/g07_xrs_1m_19960301_19960331.csv 0
# 1996/g08_xrs_1m_19960401_19960430.csv 0
# 1996/g09_xrs_1m_19960501_19960531.csv 0
# 1996/g08_xrs_1m_19960601_19960630.csv 0
# 1996/g09_xrs_1m_19960701_19960731.csv 0
# 1996/g08_xrs_1m_19960801_19960831.csv 0
# 1996/g09_xrs_1m_19960901_19960930.csv 0
# 1996/g08_xrs_1m_19961001_19961031.csv 0
# 1996/g08_xrs_1m_19961101_19961130.csv 0
# 1996/g09_xrs_1m_19961201_19961231.csv 0
# 1997/g09_xrs_1m_19970101_19970131.csv 0
# 1997/g09_xrs_1m_19970201_19970228.csv 0
# 1997/g09_xrs_1m_19970301_19970331.csv 0
# 1997/g08_xrs_1m_19970401_19970430.csv 0
# 1997/g09_xrs_1m_19970501_19970531.csv 0
# 1997/g08_xrs_1m_19970601_19970630.csv 0
# 1997/g09_xrs_1m_19970701_19970731.csv 0
# 1997/g08_xrs_1m_19970801_19970831.csv 0
# 1997/g08_xrs_1m_19970901_19970930.csv 0
# 1997/g09_xrs_1m_19971001_19971031.csv 0
# 1997/g09_xrs_1m_19971101_19971130.csv 0
# 1997/g09_xrs_1m_19971201_19971231.csv 0
# 1998/g08_xrs_1m_19980101_19980131.csv 0
# 1998/g08_xrs_1m_19980201_19980228.csv 0
# 1998/g09_xrs_1m_19980301_19980331.csv 0
# 1998/g08_xrs_1m_19980401_19980430.csv 0
# 1998/g09_xrs_1m_19980501_19980531.csv 0
# 1998/g08_xrs_1m_19980601_19980630.csv 0
# 1998/g08_xrs_1m_19980701_19980731.csv 0
# 1998/g10_xrs_1m_19980801_19980831.csv 0
# 1998/g08_xrs_1m_19980901_19980930.csv 0
# 1998/g08_xrs_1m_19981001_19981031.csv 0
# 1998/g08_xrs_1m_19981101_19981130.csv 0
# 1998/g10_xrs_1m_19981201_19981231.csv 0
# 1999/g10_xrs_1m_19990101_19990131.csv 0
# 1999/g10_xrs_1m_19990201_19990228.csv 0
# 1999/g08_xrs_1m_19990301_19990331.csv 0
# 1999/g08_xrs_1m_19990401_19990430.csv 0
# 1999/g08_xrs_1m_19990501_19990531.csv 0
# 1999/g08_xrs_1m_19990601_19990630.csv 0
# 1999/g08_xrs_1m_19990701_19990731.csv 0
# 1999/g08_xrs_1m_19990801_19990831.csv 0
# 1999/g08_xrs_1m_19990901_19990930.csv 0
# 1999/g10_xrs_1m_19991001_19991031.csv 0
# 1999/g08_xrs_1m_19991101_19991130.csv 0
# 1999/g08_xrs_1m_19991201_19991231.csv 0
# 2000/g10_xrs_1m_20000101_20000131.csv 0
# 2000/g10_xrs_1m_20000201_20000229.csv 0
# 2000/g08_xrs_1m_20000301_20000331.csv 0
# 2000/g08_xrs_1m_20000401_20000430.csv 0
# 2000/g10_xrs_1m_20000501_20000531.csv 0
# 2000/g08_xrs_1m_20000601_20000630.csv 0
# 2000/g08_xrs_1m_20000701_20000731.csv 0
# 2000/g10_xrs_1m_20000801_20000831.csv 0
# 2000/g10_xrs_1m_20000901_20000930.csv 0
# 2000/g08_xrs_1m_20001001_20001031.csv 0
# 2000/g08_xrs_1m_20001101_20001130.csv 0
# 2000/g10_xrs_1m_20001201_20001231.csv 0
# 2001/g10_xrs_1m_20010101_20010131.csv 0
# 2001/g10_xrs_1m_20010201_20010228.csv 0
# 2001/g08_xrs_1m_20010301_20010331.csv 0
# 2001/g10_xrs_1m_20010401_20010430.csv 0
# 2001/g08_xrs_1m_20010501_20010531.csv 0
# 2001/g08_xrs_1m_20010601_20010630.csv 0
# 2001/g10_xrs_1m_20010701_20010731.csv 0
# 2001/g10_xrs_1m_20010801_20010831.csv 0
# 2001/g08_xrs_1m_20010901_20010930.csv 0
# 2001/g10_xrs_1m_20011001_20011031.csv 0
# 2001/g08_xrs_1m_20011101_20011130.csv 0
# 2001/g10_xrs_1m_20011201_20011231.csv 0
# 2002/g10_xrs_1m_20020101_20020131.csv 0
# 2002/g10_xrs_1m_20020201_20020228.csv 0
# 2002/g08_xrs_1m_20020301_20020331.csv 0
# 2002/g10_xrs_1m_20020401_20020430.csv 0
# 2002/g10_xrs_1m_20020501_20020531.csv 0
# 2002/g08_xrs_1m_20020601_20020630.csv 0
# 2002/g10_xrs_1m_20020701_20020731.csv 0
# 2002/g08_xrs_1m_20020801_20020831.csv 0
# 2002/g08_xrs_1m_20020901_20020930.csv 0
# 2002/g10_xrs_1m_20021001_20021031.csv 0
# 2002/g08_xrs_1m_20021101_20021130.csv 0
# 2002/g10_xrs_1m_20021201_20021231.csv 0
# 2003/g10_xrs_1m_20030101_20030131.csv 0
# 2003/g12_xrs_1m_20030201_20030228.csv 0
# 2003/g12_xrs_1m_20030301_20030331.csv 0
# 2003/g10_xrs_1m_20030401_20030430.csv 0
# 2003/g12_xrs_1m_20030501_20030531.csv 0
# 2003/g12_xrs_1m_20030601_20030630.csv 0
# 2003/g10_xrs_1m_20030701_20030731.csv 0
# 2003/g10_xrs_1m_20030801_20030831.csv 0
# 2003/g12_xrs_1m_20030901_20030930.csv 0
# 2003/g12_xrs_1m_20031001_20031031.csv 0
# 2003/g10_xrs_1m_20031101_20031130.csv 0
# 2003/g12_xrs_1m_20031201_20031231.csv 0
# 2004/g12_xrs_1m_20040101_20040131.csv 0
# 2004/g12_xrs_1m_20040201_20040229.csv 0
# 2004/g12_xrs_1m_20040301_20040331.csv 0
# 2004/g10_xrs_1m_20040401_20040430.csv 0
# 2004/g12_xrs_1m_20040501_20040531.csv 0
# 2004/g12_xrs_1m_20040601_20040630.csv 0
# 2004/g10_xrs_1m_20040701_20040731.csv 0
# 2004/g10_xrs_1m_20040801_20040831.csv 0
# 2004/g12_xrs_1m_20040901_20040930.csv 0
# 2004/g12_xrs_1m_20041001_20041031.csv 0
# 2004/g12_xrs_1m_20041101_20041130.csv 0
# 2004/g10_xrs_1m_20041201_20041231.csv 0
# 2005/g12_xrs_1m_20050101_20050131.csv 0
# 2005/g12_xrs_1m_20050201_20050228.csv 0
# 2005/g12_xrs_1m_20050301_20050331.csv 0
# 2005/g12_xrs_1m_20050401_20050430.csv 0
# 2005/g12_xrs_1m_20050501_20050531.csv 0
# 2005/g10_xrs_1m_20050601_20050630.csv 0
# 2005/g10_xrs_1m_20050701_20050731.csv 0
# 2005/g12_xrs_1m_20050801_20050831.csv 0
# 2005/g10_xrs_1m_20050901_20050930.csv 0
# 2005/g10_xrs_1m_20051001_20051031.csv 0
# 2005/g12_xrs_1m_20051101_20051130.csv 0
# 2005/g12_xrs_1m_20051201_20051231.csv 0
# 2006/g12_xrs_1m_20060101_20060131.csv 0
# 2006/g10_xrs_1m_20060201_20060228.csv 0
# 2006/g12_xrs_1m_20060301_20060331.csv 0
# 2006/g10_xrs_1m_20060401_20060430.csv 0
# 2006/g10_xrs_1m_20060501_20060531.csv 0
# 2006/g12_xrs_1m_20060601_20060630.csv 0
# 2006/g12_xrs_1m_20060701_20060731.csv 0
# 2006/g11_xrs_1m_20060801_20060831.csv 0
# 2006/g12_xrs_1m_20060901_20060930.csv 0
# 2006/g11_xrs_1m_20061001_20061031.csv 0
# 2006/g11_xrs_1m_20061101_20061130.csv 0
# 2006/g11_xrs_1m_20061201_20061231.csv 0
# 2007/g12_xrs_1m_20070101_20070131.csv 0
# 2007/g12_xrs_1m_20070201_20070228.csv 0
# 2007/g12_xrs_1m_20070301_20070331.csv 0
# 2007/g10_xrs_1m_20070401_20070430.csv 0
# 2007/g11_xrs_1m_20070501_20070531.csv 0
# 2007/g10_xrs_1m_20070601_20070630.csv 0
# 2007/g11_xrs_1m_20070701_20070731.csv 0
# 2007/g11_xrs_1m_20070801_20070831.csv 0
# 2007/g11_xrs_1m_20070901_20070930.csv 0
# 2007/g10_xrs_1m_20071001_20071031.csv 0
# 2007/g11_xrs_1m_20071101_20071130.csv 0
# 2007/g11_xrs_1m_20071201_20071231.csv 0
# 2008/g11_xrs_1m_20080101_20080131.csv 0
# 2008/g10_xrs_1m_20080201_20080229.csv 0
# 2008/g10_xrs_1m_20080301_20080331.csv 0
# 2008/g10_xrs_1m_20080401_20080430.csv 0
# 2008/g10_xrs_1m_20080501_20080531.csv 0
# 2008/g10_xrs_1m_20080601_20080630.csv 0
# 2008/g10_xrs_1m_20080701_20080731.csv 0
# 2008/g10_xrs_1m_20080801_20080831.csv 0
# 2008/g10_xrs_1m_20080901_20080930.csv 0
# 2008/g10_xrs_1m_20081001_20081031.csv 0
# 2008/g10_xrs_1m_20081101_20081130.csv 0
# 2008/g10_xrs_1m_20081201_20081231.csv 0
# 2009/g10_xrs_1m_20090101_20090131.csv 0
# 2009/g10_xrs_1m_20090201_20090228.csv 0
# 2009/g10_xrs_1m_20090301_20090331.csv 0
# 2009/g10_xrs_1m_20090401_20090430.csv 0
# 2009/g10_xrs_1m_20090501_20090531.csv 0
# 2009/g10_xrs_1m_20090601_20090630.csv 0
# 2009/g10_xrs_1m_20090701_20090731.csv 0
# 2009/g10_xrs_1m_20090801_20090831.csv 0
# 2009/g14_xrs_1m_20090901_20090930.csv 0
# 2009/g10_xrs_1m_20091001_20091031.csv 0
# 2009/g10_xrs_1m_20091101_20091130.csv 0
# 2009/g10_xrs_1m_20091201_20091231.csv 0
# 2010/g14_xrs_1m_20100101_20100131.csv 0
# 2010/g14_xrs_1m_20100201_20100228.csv 0
# 2010/g14_xrs_1m_20100301_20100331.csv 0
# 2010/g14_xrs_1m_20100401_20100430.csv 0
# 2010/g14_xrs_1m_20100501_20100531.csv 0
# 2010/g14_xrs_1m_20100601_20100630.csv 0
# 2010/g14_xrs_1m_20100701_20100731.csv 0
# 2010/g14_xrs_1m_20100801_20100831.csv 0
# 2010/g14_xrs_1m_20100901_20100930.csv 0
# 2010/g15_xrs_1m_20101001_20101031.csv 0
# 2010/g15_xrs_1m_20101101_20101130.csv 0
# 2010/g15_xrs_1m_20101201_20101231.csv 0
# 2011/g15_xrs_1m_20110101_20110131.csv 0
# 2011/g15_xrs_1m_20110201_20110228.csv 0
# 2011/g15_xrs_1m_20110301_20110331.csv 0
# 2011/g15_xrs_1m_20110401_20110430.csv 0
# 2011/g15_xrs_1m_20110501_20110531.csv 0
# 2011/g15_xrs_1m_20110601_20110630.csv 0
# 2011/g15_xrs_1m_20110701_20110731.csv 0
# 2011/g15_xrs_1m_20110801_20110831.csv 0
# 2011/g15_xrs_1m_20110901_20110930.csv 0
# 2011/g15_xrs_1m_20111001_20111031.csv 0
# 2011/g15_xrs_1m_20111101_20111130.csv 0
# 2011/g15_xrs_1m_20111201_20111231.csv 0
# 2012/g15_xrs_1m_20120101_20120131.csv 0
# 2012/g15_xrs_1m_20120201_20120229.csv 0
# 2012/g15_xrs_1m_20120401_20120430.csv 0
# 2012/g15_xrs_1m_20120501_20120531.csv 0
# 2012/g15_xrs_1m_20120601_20120630.csv 0
# 2012/g15_xrs_1m_20120701_20120731.csv 0
# 2012/g15_xrs_1m_20120801_20120831.csv 0
# 2012/g15_xrs_1m_20120901_20120930.csv 0
# 2012/g14_xrs_1m_20121001_20121031.csv 0
# 2012/g15_xrs_1m_20121101_20121130.csv 0
# 2012/g15_xrs_1m_20121201_20121231.csv 0
# 2013/g15_xrs_1m_20130101_20130131.csv 0
# 2013/g15_xrs_1m_20130201_20130228.csv 0
# 2013/g15_xrs_1m_20130301_20130331.csv 0
# 2013/g15_xrs_1m_20130401_20130430.csv 0
# 2013/g15_xrs_1m_20130501_20130531.csv 0
# 2013/g15_xrs_1m_20130601_20130630.csv 0
# 2013/g15_xrs_1m_20130701_20130731.csv 0
# 2013/g15_xrs_1m_20130801_20130831.csv 0
# 2013/g15_xrs_1m_20130901_20130930.csv 0
# 2013/g15_xrs_1m_20131001_20131031.csv 0
# 2013/g15_xrs_1m_20131101_20131130.csv 0
# 2013/g15_xrs_1m_20131201_20131231.csv 0
# 2014/g15_xrs_1m_20140101_20140131.csv 0
# 2014/g15_xrs_1m_20140201_20140228.csv 0
# 2014/g15_xrs_1m_20140301_20140331.csv 0
# 2014/g15_xrs_1m_20140401_20140430.csv 0
# 2014/g15_xrs_1m_20140501_20140531.csv 0
# 2014/g15_xrs_1m_20140601_20140630.csv 0
# 2014/g15_xrs_1m_20140701_20140731.csv 0
# 2014/g15_xrs_1m_20140801_20140831.csv 0
# 2014/g15_xrs_1m_20140901_20140930.csv 0
# 2014/g15_xrs_1m_20141001_20141031.csv 0
# 2014/g15_xrs_1m_20141101_20141130.csv 0
# 2014/g15_xrs_1m_20141201_20141231.csv 0
# 2015/g15_xrs_1m_20150101_20150131.csv 0
# 2015/g15_xrs_1m_20150201_20150228.csv 0
# 2015/g15_xrs_1m_20150301_20150331.csv 0
# 2015/g15_xrs_1m_20150401_20150430.csv 0
# 2015/g15_xrs_1m_20150501_20150531.csv 0
# 2015/g13_xrs_1m_20150601_20150630.csv 0
# 2015/g15_xrs_1m_20150701_20150731.csv 0
# 2015/g13_xrs_1m_20150801_20150831.csv 0
# 2015/g15_xrs_1m_20150901_20150930.csv 0
# 2015/g13_xrs_1m_20151001_20151031.csv 0
# 2015/g15_xrs_1m_20151101_20151130.csv 0
# 2015/g13_xrs_1m_20151201_20151231.csv 0
# 2016/g15_xrs_1m_20160101_20160131.csv 0
# 2016/g15_xrs_1m_20160201_20160229.csv 0
# 2016/g15_xrs_1m_20160401_20160430.csv 0
# 2016/g14_xrs_1m_20160501_20160531.csv 0
# 2016/g15_xrs_1m_20160601_20160630.csv 0
# 2016/g15_xrs_1m_20160701_20160731.csv 0
# 2016/g13_xrs_1m_20160801_20160831.csv 0
# 2016/g13_xrs_1m_20160901_20160930.csv 0
# 2016/g13_xrs_1m_20161001_20161031.csv 0
# 2016/g15_xrs_1m_20161101_20161130.csv 0
# 2016/g15_xrs_1m_20161201_20161231.csv 0
# 2017/g13_xrs_1m_20170101_20170131.csv 0
# 2017/g13_xrs_1m_20170201_20170228.csv 0
# 2017/g15_xrs_1m_20170301_20170331.csv 0
# 2017/g15_xrs_1m_20170401_20170430.csv 0
# 2017/g15_xrs_1m_20170501_20170531.csv 0
# 2017/g13_xrs_1m_20170601_20170630.csv 0
# 2017/g15_xrs_1m_20170701_20170731.csv 0
# 2017/g13_xrs_1m_20170801_20170831.csv 0
# 2017/g15_xrs_1m_20170901_20170930.csv 0
# 2017/g13_xrs_1m_20171001_20171031.csv 0
# 2017/g13_xrs_1m_20171101_20171130.csv 0
# 2017/g15_xrs_1m_20171201_20171231.csv 0
# 2018/g14_xrs_1m_20180101_20180131.csv 0
# 2018/g14_xrs_1m_20180201_20180228.csv 0
# 2018/g15_xrs_1m_20180301_20180331.csv 0
# 2018/g14_xrs_1m_20180401_20180430.csv 0
# 2018/g14_xrs_1m_20180501_20180531.csv 0
# 2018/g14_xrs_1m_20180601_20180630.csv 0
# 2018/g14_xrs_1m_20180701_20180731.csv 0
# 2018/g14_xrs_1m_20180801_20180831.csv 0
# 2018/g15_xrs_1m_20180901_20180930.csv 0
# 2018/g14_xrs_1m_20181001_20181031.csv 0
# 2018/g14_xrs_1m_20181101_20181130.csv 0
# 2018/g14_xrs_1m_20181201_20181231.csv 0
# 2019/g15_xrs_1m_20190101_20190131.csv 0
# 2019/g14_xrs_1m_20190201_20190228.csv 0
# 2019/g14_xrs_1m_20190301_20190331.csv 0
# 2019/g15_xrs_1m_20190401_20190430.csv 0
# 2019/g15_xrs_1m_20190501_20190531.csv 0
# 2019/g14_xrs_1m_20190601_20190630.csv 0
# 2019/g14_xrs_1m_20190701_20190731.csv 0
# 2019/g14_xrs_1m_20190801_20190831.csv 0
# 2019/g15_xrs_1m_20190901_20190930.csv 0
# 2019/g14_xrs_1m_20191001_20191031.csv 0
# 2019/g14_xrs_1m_20191101_20191130.csv 0
# 2019/g15_xrs_1m_20191201_20191231.csv 0
# 2020/g15_xrs_1m_20200101_20200131.csv 0
# 2020/g14_xrs_1m_20200201_20200229.csv 0

# %%
## merge all dataframe to get a continuous data file
dataframes = []
for file_name in file_names:
    df = pd.read_csv(os.path.join(OUT_DIR, file_name))
    dataframes.append(df)

# Concatenate the list of DataFrames into one DataFrame
concatenated_df = pd.concat(dataframes, ignore_index=True)
concatenated_df.to_csv("sol_22_23_24_data_no_missing_v2.0.csv", index = False)

# %%
concatenated_df.describe()
# Out:
#                  xs            xl
# count  1.787904e+07  1.787904e+07
# mean   5.574662e+00  5.574662e+00
# std    4.269196e+02  4.269196e+02
# min   -1.157632e-08 -1.131665e-08
# 25%    1.160000e-09  1.550000e-09
# 50%    4.646900e-09  6.890000e-09
# 75%    1.690000e-08  3.560000e-08
# max    3.270000e+04  3.270000e+04

# %%
## As there is a buf in the data that is why it is showing the max value 32700
max_value = concatenated_df['xs'].max()
min_value = concatenated_df['xs'].min()

print(f"Max value of column xs: {max_value}")
print(f"Min value of column xs: {min_value}")
# Out:
# Max value of column xs: 32700.0
# Min value of column xs: -1.1576319354838711e-08
