# %%
import pandas as pd

# %%
import csv
counter  = 0
data_dict = {}
starting_point_found = False

starting_point = ['time_tag', 'A_QUAL_FLAG', 'A_NUM_PTS', 'A_AVG', 'B_QUAL_FLAG', 'B_NUM_PTS', 'B_AVG']
for col in starting_point:
    data_dict[col] = []

with open('g15_xrs_1m_20180101_20180131.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        counter += 1
        
        if row == starting_point:
            starting_point_found = True
            continue

        if starting_point_found:
            print(row)
            for i, col in enumerate(starting_point):
                data_dict[col].append(row[i])
        
        if counter == 3000000:
            break
df = pd.DataFrame.from_dict(data_dict)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
df
# Out:
#                       time_tag A_QUAL_FLAG A_NUM_PTS       A_AVG B_QUAL_FLAG
# 0      2018-01-01 00:00:00.000           0        29  6.0983E-09           0  \
# 1      2018-01-01 00:01:00.000           0        30  5.3541E-09           0
# 2      2018-01-01 00:02:00.000           0        29  5.7909E-09           0
# 3      2018-01-01 00:03:00.000           0        29  5.7140E-09           0
# 4      2018-01-01 00:04:00.000           0        30  6.4685E-09           0
# ...                        ...         ...       ...         ...         ...
# 44635  2018-01-31 23:55:00.000           0        30  4.0167E-09           0
# 44636  2018-01-31 23:56:00.000           0        29  4.9070E-09           0
# 44637  2018-01-31 23:57:00.000           0        29  3.1476E-09           0
# 44638  2018-01-31 23:58:00.000           0        29  4.4458E-09           0
# 44639  2018-01-31 23:59:00.000           0        30  4.6854E-09           0
#
#       B_NUM_PTS       B_AVG
# 0            29  3.9185E-08
# 1            30  4.1983E-08
# 2            29  3.9728E-08
# 3            29  3.6923E-08
# 4            30  4.1283E-08
# ...         ...         ...
# 44635        30  2.8342E-08
# 44636        29  3.1224E-08
# 44637        29  2.2360E-08
# 44638        29  2.1727E-08
# 44639        30  2.3708E-08
#
# [44640 rows x 7 columns]

# %%
import urllib.request
...
# Download the file from `url` and save it locally under `file_name`:
urllib.request.urlretrieve("https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/avg/2018/01/goes15/csv/g15_xrs_1m_20180101_20180131.csv")
# Out:
# ('/tmp/tmp1sgtfa2i', <http.client.HTTPMessage at 0x7fbe00593c10>)

# %%
import urllib.request
import shutil
url = "https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/avg/2018/01/goes15/csv/g15_xrs_1m_20180101_20180131.csv"
...
# Download the file from `url` and save it locally under `file_name`:
with urllib.request.urlopen(url) as response, open("file_name.csv", 'wb') as out_file:
    shutil.copyfileobj(response, out_file)

# %%
from datetime import datetime

# %%
"""
https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/avg/2016/01/goes15/csv/g15_xrs_1m_20160101_20160131.csv

https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/avg/2018/01/goes15/csv/g15_xrs_1m_20180101_20180131.csv
"""

# %%
import datetime
numdays = 500
base = datetime.datetime.today()
date_list = [base - datetime.timedelta(days=x) for x in range(numdays)]
#date_list

# %%
from dateutil import rrule
from datetime import datetime

year = 2016
a = f"{year}0101"
b = f"{year}1231"

for dt in rrule.rrule(rrule.MONTHLY,
                      dtstart=datetime.strptime(a, '%Y%m%d'),
                      until=datetime.strptime(b, '%Y%m%d')):
    print(dt.strftime('%Y%m%d'))
# Out:
# 20160101
# 20160201
# 20160301
# 20160401
# 20160501
# 20160601
# 20160701
# 20160801
# 20160901
# 20161001
# 20161101
# 20161201

# %%
import pandas as pd
year = 2016

# %%
end_dates = pd.date_range(f"{year}-01-01", f"{year}-12-31", freq='M')
dates_in_month = []
for end_date in end_dates:
    end_date = str(end_date).strip(" ")[:10]
    splitted_end_date = end_date.split("-")
    dates_in_month.append((f"{year}{splitted_end_date[1]}01", ("").join(splitted_end_date)))
print(dates_in_month)
# Out:
# [('20160101', '20160131'), ('20160201', '20160229'), ('20160301', '20160331'), ('20160401', '20160430'), ('20160501', '20160531'), ('20160601', '20160630'), ('20160701', '20160731'), ('20160801', '20160831'), ('20160901', '20160930'), ('20161001', '20161031'), ('20161101', '20161130'), ('20161201', '20161231')]

# %%
months_ends_at
# Out:
# ['2013-01-31',
#  '2013-02-28',
#  '2013-03-31',
#  '2013-04-30',
#  '2013-05-31',
#  '2013-06-30',
#  '2013-07-31',
#  '2013-08-31',
#  '2013-09-30',
#  '2013-10-31',
#  '2013-11-30',
#  '2013-12-31']

# %%
import logging

logging.basicConfig(filename='app.log', filemode='w', format='%(levelname)s - %(message)s')
logging.warning('This will get logged to a file')

# %%
import logging

logging.basicConfig(filename='app.log', filemode='w')
logging.warning('This will get logged to a file')

# %%
import logging

logging.basicConfig(filename='app.log', filemode='w', format='%(name)s - %(levelname)s - %(message)s')
logging.warning('This will get logged to a file')
logging.info('Admin logged in')

# %%
import logging

logging.basicConfig(format='%(asctime)s - %(message)s', level=logging.INFO)
logging.info('Admin logged in')
# Out:
# 2023-05-19 02:20:59,448 - Admin logged in

# %%
list_missing_intervals = []
list_missing_length = []
df = pd.read_csv("data/2012/g15_xrs_1m_20120101_20120131.csv")
df_missing_values = df.loc[df['A_AVG'] == -99999]
missing_size = df_missing_values.shape[0]
missing_indexes = df_missing_values.index.tolist()
df_missing_values
# Out:
#                       time_tag  A_QUAL_FLAG  A_NUM_PTS    A_AVG  B_QUAL_FLAG
# 6960   2012-01-05 20:00:00.000      1048576         30 -99999.0      1048576  \
# 6961   2012-01-05 20:01:00.000      1048576         29 -99999.0      1048576
# 6962   2012-01-05 20:02:00.000      1048576         29 -99999.0      1048576
# 6963   2012-01-05 20:03:00.000      1048576         30 -99999.0      1048576
# 6964   2012-01-05 20:04:00.000      1048576         29 -99999.0      1048576
# 6965   2012-01-05 20:05:00.000      1048576         29 -99999.0      1048576
# 6966   2012-01-05 20:06:00.000      1048576         29 -99999.0      1048576
# 6967   2012-01-05 20:07:00.000      1048576         30 -99999.0      1048576
# 6968   2012-01-05 20:08:00.000      1048576         29 -99999.0      1048576
# 17040  2012-01-12 20:00:00.000      1048576         29 -99999.0      1048576
# 17041  2012-01-12 20:01:00.000      1048576         29 -99999.0      1048576
# 17042  2012-01-12 20:02:00.000      1048576         30 -99999.0      1048576
# 17043  2012-01-12 20:03:00.000      1048576         29 -99999.0      1048576
# 17044  2012-01-12 20:04:00.000      1048576         29 -99999.0      1048576
# 17045  2012-01-12 20:05:00.000      1048576         30 -99999.0      1048576
# 17046  2012-01-12 20:06:00.000      1048576         29 -99999.0      1048576
# 17047  2012-01-12 20:07:00.000      1048576         29 -99999.0      1048576
# 17048  2012-01-12 20:08:00.000      1048576         30 -99999.0      1048576
# 27120  2012-01-19 20:00:00.000      1048576         30 -99999.0      1048576
# 27121  2012-01-19 20:01:00.000      1048576         29 -99999.0      1048576
# 27122  2012-01-19 20:02:00.000      1048576         29 -99999.0      1048576
    nums = sorted(set(nums))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+1 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))
intervals = ranges(missing_indexes)
print(type(intervals[0]))
for interval in intervals:
    print(interval)
    st =  df.iloc[[interval[0]]].values.tolist()[0][0]
    end = df.iloc[[interval[1]]].values.tolist()[0][0]
    list_missing_intervals.append(f"{st} to {end}")
    list_missing_length.append(interval[1] - interval[0] + 1)
    #print(f"{st} to {end}")
# Out:
# <class 'tuple'>
# (6960, 6968)
# (17040, 17048)
# (27120, 27128)
# (37200, 37208)
# (42885, 42899)

# %%
import os
import csv
import json
import logging
import shutil
import pandas as pd
import urllib.request
from typing import Tuple
logging.basicConfig(level=logging.DEBUG)

missing_infos = {}

def get_year_range(start_yr: int, end_yr: int) -> list[int]:
    # to get the year's based on range
    return [yr + 1 for yr in range(start_yr - 1, end_yr)]

def make_folder(years: list[int]):
    #create folder to hold the data
    for yr in years:
        os.makedirs(f"data/{yr}", exist_ok = True)

def get_month_ranges_in_year(year: int) -> Tuple[list[tuple()], list[str]]:
    #get the month's date range from january to december in a given year
    month_numbers = []
    dates_in_month = []
    end_dates = pd.date_range(f"{year}-01-01", f"{year}-12-31", freq='M')
    for end_date in end_dates:
        end_date = str(end_date).strip(" ")[:10]
        splitted_end_date = end_date.split("-")
        month_numbers.append(splitted_end_date[1])
        dates_in_month.append((f"{year}{splitted_end_date[1]}01", ("").join(splitted_end_date)))
    
    return dates_in_month, month_numbers
 
def build_file_name(start: str, end: str) -> str:
    #build the file name of the csv file
    return f"g15_xrs_1m_{start}_{end}.csv"

def build_file_URL(year: int, month: str, file_name: str) -> str:
    #build the URL for file path of the csv file
    return f"https://www.ncei.noaa.gov/data/goes-space-environment-monitor/access/avg/{year}/{month}/goes15/csv/{file_name}"

def download_file(year: int, url: str, file_name: str) -> None:
    # download the file from `url` and save it locally under `file_name`:
    try:
        with urllib.request.urlopen(url) as response, open(f"data/{year}/{file_name}", 'wb') as out_file:
            shutil.copyfileobj(response, out_file)
    except:
        logging.error(f"URL {url}  not found")
        pass

def get_continuous_ranges(nums: list) -> list[Tuple]:
    # helper function to get continuous interval
    nums = sorted(set(nums))
    gaps = [[s, e] for s, e in zip(nums, nums[1:]) if s+1 < e]
    edges = iter(nums[:1] + sum(gaps, []) + nums[-1:])
    return list(zip(edges, edges))
    
def get_missing_info(file_path: str) -> Tuple[list[str], list[int]]:
    # get different missing data informations
    list_missing_intervals = []
    list_missing_length = []
    
    df = pd.read_csv(file_path)
    df_missing_values = df.loc[df['A_AVG'] == -99999]
    missing_indexes = df_missing_values.index.tolist()

    intervals = get_continuous_ranges(missing_indexes)
    for interval in intervals:
        st =  df.iloc[[interval[0]]].values.tolist()[0][0]
        end = df.iloc[[interval[1]]].values.tolist()[0][0]
        list_missing_intervals.append(f"{st} to {end}")
        list_missing_length.append(interval[1] - interval[0] + 1)
    
    return list_missing_intervals, list_missing_length

def pre_process_data(year: int, month: str, file_name: str) -> None:
    """
    Extract the important rows and save them as csv
    Also get some information about missing values
    """
    data_dict = {}
    yearly_missing_dict = {}
    missing_row_counter = 0
    
    csv_filename_with_dir = f"data/{year}/{file_name}"
    starting_point_found = False
    
    starting_point = ['time_tag', 'A_QUAL_FLAG', 'A_NUM_PTS', 'A_AVG', 'B_QUAL_FLAG', 'B_NUM_PTS', 'B_AVG']
    for col in starting_point:
        data_dict[col] = []
    
    with open(csv_filename_with_dir, newline='') as csvfile:
        reader = csv.reader(csvfile, delimiter=',', quotechar='|')
        for row in reader:
            if row == starting_point:
                starting_point_found = True
                continue
    
            if starting_point_found:
                for i, col in enumerate(starting_point):
                    data_dict[col].append(row[i])

    df = pd.DataFrame.from_dict(data_dict)
    df.to_csv(csv_filename_with_dir, index = False)
    
    yearly_missing_dict["number of total rows"] = df.shape[0]
    list_missing_intervals, list_missing_length = get_missing_info(csv_filename_with_dir)
    yearly_missing_dict["number of missing rows"] = sum(list_missing_length)
    yearly_missing_dict["missing rows each interval"] = list_missing_length
    yearly_missing_dict["missing intervals"] = list_missing_intervals
    missing_infos[month] = yearly_missing_dict
    
    with open(f"data/{year}_summary.json", "w") as fp:
        json.dump(missing_infos, fp)

def download_data_by_year(year: int) -> None:
    """
    Need some steps to get the data from www.ncei.noaa.gov
        -> Need date range of the year by month
        -> Need the filename
        -> Need the URL for file in NOAA website
        -> Download the data
    """
    date_range_in_month, month_numbers = get_month_ranges_in_year(year)
    for i, date_range in enumerate(date_range_in_month):
        file_name = build_file_name(date_range[0], date_range[1])
        file_url = build_file_URL(year, month_numbers[i], file_name)
        download_file(year, file_url, file_name)
        logging.info(f"Download completed of {file_name}")
        pre_process_data(year, month_numbers[i], file_name)
        logging.info(f"Pre-processing completed of {file_name}")

    
def main() -> None:
    #main function caller
    start_yr = int(input("Enter start year:"))
    end_yr = int(input("Enter end year:"))

    if start_yr > end_yr:
        logging.error("Start year can not be greater than end date")
        return
    
    years = get_year_range(start_yr, end_yr)
    make_folder(years)
    for yr in years:
        download_data_by_year(yr)
        logging.info(f"Data downloaded for year {yr}")

if __name__ == '__main__':
    main()
# Out:
# Enter start year: 2012
# Enter end year: 2019
# INFO:root:Download completed of g15_xrs_1m_20120101_20120131.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120101_20120131.csv
# INFO:root:Download completed of g15_xrs_1m_20120201_20120229.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120201_20120229.csv
# INFO:root:Download completed of g15_xrs_1m_20120301_20120331.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120301_20120331.csv
# INFO:root:Download completed of g15_xrs_1m_20120401_20120430.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120401_20120430.csv
# INFO:root:Download completed of g15_xrs_1m_20120501_20120531.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120501_20120531.csv
# INFO:root:Download completed of g15_xrs_1m_20120601_20120630.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120601_20120630.csv
# INFO:root:Download completed of g15_xrs_1m_20120701_20120731.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120701_20120731.csv
# INFO:root:Download completed of g15_xrs_1m_20120801_20120831.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120801_20120831.csv
# INFO:root:Download completed of g15_xrs_1m_20120901_20120930.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20120901_20120930.csv
# INFO:root:Download completed of g15_xrs_1m_20121001_20121031.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20121001_20121031.csv
# INFO:root:Download completed of g15_xrs_1m_20121101_20121130.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20121101_20121130.csv
# INFO:root:Download completed of g15_xrs_1m_20121201_20121231.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20121201_20121231.csv
# INFO:root:Data downloaded for year 2012
# INFO:root:Download completed of g15_xrs_1m_20130101_20130131.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130101_20130131.csv
# INFO:root:Download completed of g15_xrs_1m_20130201_20130228.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130201_20130228.csv
# INFO:root:Download completed of g15_xrs_1m_20130301_20130331.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130301_20130331.csv
# INFO:root:Download completed of g15_xrs_1m_20130401_20130430.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130401_20130430.csv
# INFO:root:Download completed of g15_xrs_1m_20130501_20130531.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130501_20130531.csv
# INFO:root:Download completed of g15_xrs_1m_20130601_20130630.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20130601_20130630.csv
# INFO:root:Download completed of g15_xrs_1m_20130701_20130731.csv
# INFO:root:Pre-processing completed of g15_xrs_1m_20